# %% [markdown]
# **Versions of tensorflow and keras that worked on my computer**

# %%
# !pip install tensorflow-gpu==2.4.0

# %%
# !pip install tensorflow==2.4.0

# %%
# !pip install keras==2.4.0

# %% [markdown]
# **Mount google drive and unzip photos**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
! unzip "/content/gdrive/MyDrive/CS271Project/train-faces.zip"

# %% [markdown]
# **Imports**

# %%
import os
import pandas as pd
import numpy as np
import cv2

from imageio import imread
from skimage.transform import resize
from tqdm import tqdm

# %%
# !pip install keras_vggface

# %%
# !pip install keras_applications

# %%
from tensorflow import keras 
from collections import defaultdict
from glob import glob
from random import choice, sample

from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.layers import Input, Dense, GlobalMaxPool2D, GlobalAvgPool2D, Concatenate, Multiply, Dropout, Subtract, Add
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers

from keras_vggface import utils
from keras_vggface.vggface import VGGFace

# %%
# make sure tensorflow is using GPUs

import tensorflow.compat.v1 as tf

tf.disable_v2_behavior()  #disable for tensorFlow V2
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %% [markdown]
# **Baseline code, provided from Kaggle competition**

# %%
# Organizing file paths to correctly label related faces

train_folders_path = "/content/train-faces/**/**/*.jpg"
train_file_path = "/content/gdrive/MyDrive/CS271Project/train-pairs.csv"
val_families = "F09"

all_images = glob(train_folders_path)

# Separating folder 9 as the validation set
train_images = [x for x in all_images if val_families not in x]
val_images = [x for x in all_images if val_families in x]

train_person_to_images_map = defaultdict(list)

# Each person has a unique number, most have multiple images
ppl = [x.split("/")[-3] + "/" + x.split("/")[-2] for x in all_images]

for x in train_images:
    train_person_to_images_map[x.split("/")[-3] + "/" + x.split("/")[-2]].append(x)

val_person_to_images_map = defaultdict(list)

for x in val_images:
    val_person_to_images_map[x.split("/")[-3] + "/" + x.split("/")[-2]].append(x)

# Reading the pairs of people who are related
relationships = pd.read_csv(train_file_path)
relationships = list(zip(relationships.p1.values, relationships.p2.values))
relationships = [x for x in relationships if x[0] in ppl and x[1] in ppl]

# Related images in training and validation sets
train = [x for x in relationships if val_families not in x[0]]
val = [x for x in relationships if val_families in x[0]]

# %%
# Read, resize, reshape image

def read_img(path):
    img = cv2.imread(path)
    img = np.array(img).astype(np.float)
    img = cv2.resize(img,(224, 224))  
    img = np.reshape(img,[224,224,3])
    return utils.preprocess_input(img, version=2)

# %%
# Generator for model.fit
# X1 and X2 are image outputs for person 1 and person 2
# label shows if X1 and X2 are related (1) or not (0), one label per pair
# Batch size dictates how many (X1, X2) pairs and number of labels

def gen(list_tuples, person_to_images_map, batch_size=16):

    # list of people
    ppl = list(person_to_images_map.keys())

    while True:

        batch_tuples = sample(list_tuples, batch_size // 2)
        labels = [1] * len(batch_tuples)

        while len(batch_tuples) < batch_size:
            p1 = choice(ppl)
            p2 = choice(ppl)

            if p1 != p2 and (p1, p2) not in list_tuples and (p2, p1) not in list_tuples:
                batch_tuples.append((p1, p2))
                labels.append(0)

        for x in batch_tuples:
            if not len(person_to_images_map[x[0]]):
                print(x[0])

        X1 = [choice(person_to_images_map[x[0]]) for x in batch_tuples]
        X1 = np.array([read_img(x) for x in X1])
      
        X2 = [choice(person_to_images_map[x[1]]) for x in batch_tuples]
        X2 = np.array([read_img(x) for x in X2])

        labels = np.asarray(labels, dtype=np.float32)

        yield (X1, X2), labels

# %% [markdown]
# **Model 1/6**

# %%
def baseline_model1():

    input_1 = Input(shape=(224, 224, 3))
    input_2 = Input(shape=(224, 224, 3))

    base_model = VGGFace(model='resnet50', include_top=False)

    for x in base_model.layers[:-3]:
        x.trainable = True

    x1 = base_model(input_1)
    x2 = base_model(input_2)

    x1 = Concatenate(axis=-1)([GlobalMaxPool2D()(x1), GlobalAvgPool2D()(x1)])
    x2 = Concatenate(axis=-1)([GlobalMaxPool2D()(x2), GlobalAvgPool2D()(x2)])

    x3 = Subtract()([x1, x2])
    x3 = Multiply()([x3, x3])

    x = Multiply()([x1, x2])

    x = Concatenate(axis=-1)([x, x3])

    x = Dense(512, activation="relu",kernel_regularizer=regularizers.l2(0.01))(x)
    x = Dropout(0.5)(x)
    out = Dense(1, activation="sigmoid")(x)

    model = Model([input_1, input_2], out)

    model.compile(loss="binary_crossentropy", metrics=['acc'], optimizer=Adam(0.00001))

    model.summary()

    return model

# %%
file_path = "vggface1.h5"

checkpoint = ModelCheckpoint(file_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

reduce_on_plateau = ReduceLROnPlateau(monitor="val_acc", mode="max", factor=0.1, patience=10, verbose=1)

early_stop = EarlyStopping(monitor='loss', patience=5)

callbacks_list = [checkpoint, reduce_on_plateau, early_stop]

model1 = baseline_model1()
# Out:
# Downloading data from https://github.com/rcmalli/keras-vggface/releases/download/v2.0/rcmalli_vggface_tf_notop_resnet50.h5
# 94699520/94694792 [==============================] - 1s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# vggface_resnet50 (Functional)   (None, None, None, 2 23561152    input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d (GlobalMax (None, 2048)         0           vggface_resnet50[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2048)         0           vggface_resnet50[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_1 (GlobalM (None, 2048)         0           vggface_resnet50[1][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 2048)         0           vggface_resnet50[1][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 4096)         0           global_max_pooling2d[0][0]
#                                                                  global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 4096)         0           global_max_pooling2d_1[0][0]
#                                                                  global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# subtract (Subtract)             (None, 4096)         0           concatenate[0][0]
#                                                                  concatenate_1[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 4096)         0           concatenate[0][0]
#                                                                  concatenate_1[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 4096)         0           subtract[0][0]
#                                                                  subtract[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 8192)         0           multiply_1[0][0]
#                                                                  multiply[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          4194816     concatenate_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            513         dropout[0][0]
# ==================================================================================================
# Total params: 27,756,481
# Trainable params: 27,703,361
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
model1.fit(gen(train, train_person_to_images_map, batch_size=16), use_multiprocessing=True,
                    validation_data=gen(val, val_person_to_images_map, batch_size=16), epochs=50, verbose=2,
                    workers=4, callbacks=callbacks_list, steps_per_epoch=100, validation_steps=50)
# Out:
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# Epoch 1/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# Epoch 00001: val_acc improved from -inf to 0.55500, saving model to vggface1.h5
# 100/100 - 61s - loss: 14.7809 - acc: 0.5656 - val_loss: 13.9879 - val_acc: 0.5550
# Epoch 2/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00002: val_acc improved from 0.55500 to 0.59875, saving model to vggface1.h5
# 100/100 - 35s - loss: 13.1111 - acc: 0.5644 - val_loss: 12.1873 - val_acc: 0.5987
# Epoch 3/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00003: val_acc improved from 0.59875 to 0.60750, saving model to vggface1.h5
# 100/100 - 34s - loss: 11.3539 - acc: 0.6162 - val_loss: 11.1812 - val_acc: 0.6075
# Epoch 4/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00004: val_acc improved from 0.60750 to 0.63250, saving model to vggface1.h5
# 100/100 - 34s - loss: 10.7223 - acc: 0.6231 - val_loss: 11.2719 - val_acc: 0.6325
# Epoch 5/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00005: val_acc did not improve from 0.63250
# 100/100 - 32s - loss: 10.3910 - acc: 0.6456 - val_loss: 10.5940 - val_acc: 0.5962
# Epoch 6/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00006: val_acc improved from 0.63250 to 0.66250, saving model to vggface1.h5
# 100/100 - 36s - loss: 10.2746 - acc: 0.6363 - val_loss: 10.2242 - val_acc: 0.6625
# Epoch 7/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00007: val_acc improved from 0.66250 to 0.66625, saving model to vggface1.h5
# 100/100 - 34s - loss: 10.0661 - acc: 0.6781 - val_loss: 10.0834 - val_acc: 0.6662
# Epoch 8/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00008: val_acc improved from 0.66625 to 0.67875, saving model to vggface1.h5
# 100/100 - 34s - loss: 9.9961 - acc: 0.6894 - val_loss: 10.0015 - val_acc: 0.6787
# Epoch 9/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00009: val_acc improved from 0.67875 to 0.73750, saving model to vggface1.h5
# 100/100 - 34s - loss: 9.9481 - acc: 0.6806 - val_loss: 9.9297 - val_acc: 0.7375
# Epoch 10/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00010: val_acc did not improve from 0.73750
# 100/100 - 32s - loss: 9.8452 - acc: 0.7119 - val_loss: 9.9310 - val_acc: 0.7038
# Epoch 11/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00011: val_acc did not improve from 0.73750
# 100/100 - 34s - loss: 9.7554 - acc: 0.7250 - val_loss: 9.8663 - val_acc: 0.7225
# Epoch 12/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00012: val_acc did not improve from 0.73750
# 100/100 - 33s - loss: 9.6974 - acc: 0.7337 - val_loss: 10.6406 - val_acc: 0.7175
# Epoch 13/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00013: val_acc did not improve from 0.73750
# 100/100 - 33s - loss: 9.6211 - acc: 0.7225 - val_loss: 9.8213 - val_acc: 0.7175
# Epoch 14/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00014: val_acc improved from 0.73750 to 0.75375, saving model to vggface1.h5
# 100/100 - 36s - loss: 9.5781 - acc: 0.7206 - val_loss: 9.6585 - val_acc: 0.7538
# Epoch 15/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00015: val_acc did not improve from 0.75375
# 100/100 - 33s - loss: 9.4781 - acc: 0.7406 - val_loss: 9.4557 - val_acc: 0.7462
# Epoch 16/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00016: val_acc improved from 0.75375 to 0.76625, saving model to vggface1.h5
# 100/100 - 35s - loss: 9.4591 - acc: 0.7362 - val_loss: 9.6214 - val_acc: 0.7663
# Epoch 17/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00017: val_acc did not improve from 0.76625
# 100/100 - 32s - loss: 9.3761 - acc: 0.7381 - val_loss: 9.3746 - val_acc: 0.7575
# Epoch 18/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00018: val_acc did not improve from 0.76625
# 100/100 - 34s - loss: 9.3083 - acc: 0.7269 - val_loss: 9.3849 - val_acc: 0.7325
# Epoch 19/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00019: val_acc improved from 0.76625 to 0.76750, saving model to vggface1.h5
# 100/100 - 35s - loss: 9.2260 - acc: 0.7575 - val_loss: 9.2902 - val_acc: 0.7675
# Epoch 20/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00020: val_acc did not improve from 0.76750
# 100/100 - 32s - loss: 9.1764 - acc: 0.7569 - val_loss: 9.1763 - val_acc: 0.7412
# Epoch 21/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00021: val_acc did not improve from 0.76750
# 100/100 - 33s - loss: 9.0701 - acc: 0.7706 - val_loss: 9.2027 - val_acc: 0.7437
# Epoch 22/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00022: val_acc did not improve from 0.76750
# 100/100 - 34s - loss: 9.0296 - acc: 0.7644 - val_loss: 9.1716 - val_acc: 0.7575
# Epoch 23/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00023: val_acc did not improve from 0.76750
# 100/100 - 33s - loss: 8.9611 - acc: 0.7550 - val_loss: 9.0420 - val_acc: 0.7475
# Epoch 24/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00024: val_acc did not improve from 0.76750
# 100/100 - 34s - loss: 8.9019 - acc: 0.7550 - val_loss: 9.0814 - val_acc: 0.7538
# Epoch 25/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00025: val_acc did not improve from 0.76750
# 100/100 - 34s - loss: 8.7910 - acc: 0.7800 - val_loss: 8.9418 - val_acc: 0.7563
# Epoch 26/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00026: val_acc improved from 0.76750 to 0.77500, saving model to vggface1.h5
# 100/100 - 35s - loss: 8.7354 - acc: 0.7763 - val_loss: 8.7300 - val_acc: 0.7750
# Epoch 27/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00027: val_acc did not improve from 0.77500
# 100/100 - 32s - loss: 8.6440 - acc: 0.7844 - val_loss: 8.6705 - val_acc: 0.7613
# Epoch 28/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00028: val_acc improved from 0.77500 to 0.77875, saving model to vggface1.h5
# 100/100 - 36s - loss: 8.5896 - acc: 0.7581 - val_loss: 8.5812 - val_acc: 0.7788
# Epoch 29/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00029: val_acc did not improve from 0.77875
# 100/100 - 32s - loss: 8.5027 - acc: 0.7738 - val_loss: 8.5424 - val_acc: 0.7487
# Epoch 30/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00030: val_acc did not improve from 0.77875
# 100/100 - 33s - loss: 8.4529 - acc: 0.7638 - val_loss: 8.4658 - val_acc: 0.7638
# Epoch 31/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00031: val_acc did not improve from 0.77875
# 100/100 - 33s - loss: 8.3302 - acc: 0.7875 - val_loss: 8.4219 - val_acc: 0.7588
# Epoch 32/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00032: val_acc did not improve from 0.77875
# 100/100 - 33s - loss: 8.2725 - acc: 0.7862 - val_loss: 8.2459 - val_acc: 0.7688
# Epoch 33/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00033: val_acc improved from 0.77875 to 0.79625, saving model to vggface1.h5
# 100/100 - 36s - loss: 8.1966 - acc: 0.7794 - val_loss: 8.1634 - val_acc: 0.7962
# Epoch 34/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00034: val_acc did not improve from 0.79625
# 100/100 - 32s - loss: 8.1282 - acc: 0.7700 - val_loss: 8.1117 - val_acc: 0.7763
# Epoch 35/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00035: val_acc did not improve from 0.79625
# 100/100 - 33s - loss: 8.0224 - acc: 0.7981 - val_loss: 7.9974 - val_acc: 0.7713
# Epoch 36/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00036: val_acc did not improve from 0.79625
# 100/100 - 33s - loss: 7.9300 - acc: 0.7975 - val_loss: 7.9583 - val_acc: 0.7563
# Epoch 37/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00037: val_acc did not improve from 0.79625
# 100/100 - 33s - loss: 7.8443 - acc: 0.7987 - val_loss: 7.8921 - val_acc: 0.7738
# Epoch 38/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00038: val_acc did not improve from 0.79625
# 100/100 - 33s - loss: 7.7535 - acc: 0.7956 - val_loss: 7.7821 - val_acc: 0.7725
# Epoch 39/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00039: val_acc did not improve from 0.79625
# 100/100 - 33s - loss: 7.6729 - acc: 0.7956 - val_loss: 7.7165 - val_acc: 0.7812
# Epoch 40/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00040: val_acc did not improve from 0.79625
# 100/100 - 33s - loss: 7.5717 - acc: 0.8138 - val_loss: 7.5578 - val_acc: 0.7862
# Epoch 41/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00041: val_acc did not improve from 0.79625
# 100/100 - 33s - loss: 7.5049 - acc: 0.8062 - val_loss: 7.5222 - val_acc: 0.7663
# Epoch 42/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00042: val_acc did not improve from 0.79625
# 100/100 - 33s - loss: 7.4092 - acc: 0.8156 - val_loss: 7.4548 - val_acc: 0.7663
# Epoch 43/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00043: val_acc did not improve from 0.79625
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 100/100 - 35s - loss: 7.3247 - acc: 0.8000 - val_loss: 7.3527 - val_acc: 0.7588
# Epoch 44/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00044: val_acc did not improve from 0.79625
# 100/100 - 32s - loss: 7.2674 - acc: 0.8100 - val_loss: 7.3704 - val_acc: 0.7588
# Epoch 45/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00045: val_acc did not improve from 0.79625
# 100/100 - 33s - loss: 7.2449 - acc: 0.8194 - val_loss: 7.3293 - val_acc: 0.7925
# Epoch 46/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00046: val_acc did not improve from 0.79625
# 100/100 - 33s - loss: 7.2923 - acc: 0.7875 - val_loss: 7.2982 - val_acc: 0.7812
# Epoch 47/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00047: val_acc did not improve from 0.79625
# 100/100 - 33s - loss: 7.2334 - acc: 0.8281 - val_loss: 7.3150 - val_acc: 0.7638
# Epoch 48/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00048: val_acc did not improve from 0.79625
# 100/100 - 33s - loss: 7.2383 - acc: 0.8044 - val_loss: 7.3115 - val_acc: 0.7675
# Epoch 49/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00049: val_acc did not improve from 0.79625
# 100/100 - 33s - loss: 7.2373 - acc: 0.8037 - val_loss: 7.3078 - val_acc: 0.7875
# Epoch 50/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00050: val_acc did not improve from 0.79625
# 100/100 - 33s - loss: 7.1977 - acc: 0.8306 - val_loss: 7.2697 - val_acc: 0.7862

# %% [markdown]
# **Model 2/6**

# %%
def baseline_model2():

    input_1 = Input(shape=(224, 224, 3))
    input_2 = Input(shape=(224, 224, 3))

    base_model = VGGFace(model='resnet50', include_top=False)

    for x in base_model.layers[:-3]:
        x.trainable = True

    x1 = base_model(input_1)
    x2 = base_model(input_2)

    x1 = Concatenate(axis=-1)([GlobalMaxPool2D()(x1), GlobalAvgPool2D()(x1)])
    x2 = Concatenate(axis=-1)([GlobalMaxPool2D()(x2), GlobalAvgPool2D()(x2)])

    x3 = Subtract()([x1, x2])
    x3 = Multiply()([x3, x3])

    x1_2 = Multiply()([x1, x1])
    x2_2 = Multiply()([x2, x2])

    x = Subtract()([x1_2, x2_2])

    x = Concatenate(axis=-1)([x, x3])

    x = Dense(512, activation="relu",kernel_regularizer=regularizers.l2(0.01))(x)
    x = Dropout(0.5)(x)
    out = Dense(1, activation="sigmoid")(x)

    model = Model([input_1, input_2], out)

    model.compile(loss="binary_crossentropy", metrics=['acc'], optimizer=Adam(0.00001))

    model.summary()

    return model

# %%
file_path = "vggface2.h5"

checkpoint = ModelCheckpoint(file_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

reduce_on_plateau = ReduceLROnPlateau(monitor="val_acc", mode="max", factor=0.1, patience=10, verbose=1)

early_stop = EarlyStopping(monitor='loss', patience=5)

callbacks_list = [checkpoint, reduce_on_plateau, early_stop]

model2 = baseline_model2()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# vggface_resnet50 (Functional)   (None, None, None, 2 23561152    input_4[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_2 (GlobalM (None, 2048)         0           vggface_resnet50[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 2048)         0           vggface_resnet50[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_3 (GlobalM (None, 2048)         0           vggface_resnet50[1][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 2048)         0           vggface_resnet50[1][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 4096)         0           global_max_pooling2d_2[0][0]
#                                                                  global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 4096)         0           global_max_pooling2d_3[0][0]
#                                                                  global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 4096)         0           concatenate_3[0][0]
#                                                                  concatenate_3[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 4096)         0           concatenate_4[0][0]
#                                                                  concatenate_4[0][0]
# __________________________________________________________________________________________________
# subtract_1 (Subtract)           (None, 4096)         0           concatenate_3[0][0]
#                                                                  concatenate_4[0][0]
# __________________________________________________________________________________________________
# subtract_2 (Subtract)           (None, 4096)         0           multiply_3[0][0]
#                                                                  multiply_4[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 4096)         0           subtract_1[0][0]
#                                                                  subtract_1[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 8192)         0           subtract_2[0][0]
#                                                                  multiply_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          4194816     concatenate_5[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            513         dropout_1[0][0]
# ==================================================================================================
# Total params: 27,756,481
# Trainable params: 27,703,361
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
model2.fit(gen(train, train_person_to_images_map, batch_size=16), use_multiprocessing=True,
                    validation_data=gen(val, val_person_to_images_map, batch_size=16), epochs=50, verbose=2,
                    workers=4, callbacks=callbacks_list, steps_per_epoch=100, validation_steps=50)
# Out:
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# Epoch 1/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# Epoch 00001: val_acc improved from -inf to 0.60000, saving model to vggface2.h5
# 100/100 - 54s - loss: 17.0606 - acc: 0.5456 - val_loss: 15.8800 - val_acc: 0.6000
# Epoch 2/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00002: val_acc improved from 0.60000 to 0.62375, saving model to vggface2.h5
# 100/100 - 34s - loss: 14.8142 - acc: 0.5763 - val_loss: 13.1450 - val_acc: 0.6237
# Epoch 3/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00003: val_acc did not improve from 0.62375
# 100/100 - 32s - loss: 12.7821 - acc: 0.5962 - val_loss: 12.2247 - val_acc: 0.5938
# Epoch 4/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00004: val_acc did not improve from 0.62375
# 100/100 - 33s - loss: 11.7104 - acc: 0.5931 - val_loss: 11.5239 - val_acc: 0.6150
# Epoch 5/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00005: val_acc improved from 0.62375 to 0.62750, saving model to vggface2.h5
# 100/100 - 36s - loss: 11.1120 - acc: 0.5900 - val_loss: 11.2033 - val_acc: 0.6275
# Epoch 6/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00006: val_acc did not improve from 0.62750
# 100/100 - 32s - loss: 10.6265 - acc: 0.6169 - val_loss: 10.9752 - val_acc: 0.6150
# Epoch 7/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00007: val_acc did not improve from 0.62750
# 100/100 - 33s - loss: 10.4762 - acc: 0.6162 - val_loss: 10.8620 - val_acc: 0.6112
# Epoch 8/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00008: val_acc improved from 0.62750 to 0.64875, saving model to vggface2.h5
# 100/100 - 36s - loss: 10.4109 - acc: 0.5856 - val_loss: 10.2390 - val_acc: 0.6488
# Epoch 9/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00009: val_acc improved from 0.64875 to 0.65875, saving model to vggface2.h5
# 100/100 - 34s - loss: 10.2839 - acc: 0.6100 - val_loss: 10.1103 - val_acc: 0.6587
# Epoch 10/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00010: val_acc improved from 0.65875 to 0.71125, saving model to vggface2.h5
# 100/100 - 34s - loss: 10.1233 - acc: 0.6538 - val_loss: 10.0622 - val_acc: 0.7113
# Epoch 11/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00011: val_acc did not improve from 0.71125
# 100/100 - 32s - loss: 10.0742 - acc: 0.6637 - val_loss: 10.0380 - val_acc: 0.6850
# Epoch 12/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00012: val_acc did not improve from 0.71125
# 100/100 - 33s - loss: 10.0362 - acc: 0.6625 - val_loss: 9.9563 - val_acc: 0.6913
# Epoch 13/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00013: val_acc did not improve from 0.71125
# 100/100 - 33s - loss: 9.9925 - acc: 0.6538 - val_loss: 10.1876 - val_acc: 0.6888
# Epoch 14/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00014: val_acc did not improve from 0.71125
# 100/100 - 33s - loss: 9.9175 - acc: 0.6744 - val_loss: 9.9408 - val_acc: 0.6888
# Epoch 15/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00015: val_acc did not improve from 0.71125
# 100/100 - 33s - loss: 9.8790 - acc: 0.6756 - val_loss: 9.9430 - val_acc: 0.6762
# Epoch 16/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00016: val_acc did not improve from 0.71125
# 100/100 - 33s - loss: 9.8291 - acc: 0.6850 - val_loss: 9.7957 - val_acc: 0.7113
# Epoch 17/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00017: val_acc did not improve from 0.71125
# 100/100 - 34s - loss: 9.7756 - acc: 0.7006 - val_loss: 10.2169 - val_acc: 0.6750
# Epoch 18/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00018: val_acc did not improve from 0.71125
# 100/100 - 33s - loss: 9.7608 - acc: 0.6856 - val_loss: 9.7533 - val_acc: 0.6888
# Epoch 19/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00019: val_acc improved from 0.71125 to 0.72875, saving model to vggface2.h5
# 100/100 - 35s - loss: 9.6917 - acc: 0.6944 - val_loss: 9.8227 - val_acc: 0.7287
# Epoch 20/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00020: val_acc did not improve from 0.72875
# 100/100 - 32s - loss: 9.6429 - acc: 0.7063 - val_loss: 9.6884 - val_acc: 0.7262
# Epoch 21/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00021: val_acc did not improve from 0.72875
# 100/100 - 33s - loss: 9.5899 - acc: 0.7231 - val_loss: 9.6412 - val_acc: 0.7075
# Epoch 22/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00022: val_acc did not improve from 0.72875
# 100/100 - 33s - loss: 9.5345 - acc: 0.7237 - val_loss: 9.5618 - val_acc: 0.7225
# Epoch 23/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00023: val_acc did not improve from 0.72875
# 100/100 - 33s - loss: 9.4816 - acc: 0.7312 - val_loss: 9.5396 - val_acc: 0.7262
# Epoch 24/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00024: val_acc improved from 0.72875 to 0.74375, saving model to vggface2.h5
# 100/100 - 35s - loss: 9.4375 - acc: 0.7350 - val_loss: 9.4790 - val_acc: 0.7437
# Epoch 25/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00025: val_acc did not improve from 0.74375
# 100/100 - 32s - loss: 9.3596 - acc: 0.7506 - val_loss: 9.5005 - val_acc: 0.7287
# Epoch 26/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00026: val_acc improved from 0.74375 to 0.75000, saving model to vggface2.h5
# 100/100 - 35s - loss: 9.3321 - acc: 0.7444 - val_loss: 9.3808 - val_acc: 0.7500
# Epoch 27/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00027: val_acc did not improve from 0.75000
# 100/100 - 32s - loss: 9.2522 - acc: 0.7506 - val_loss: 9.2944 - val_acc: 0.7425
# Epoch 28/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00028: val_acc improved from 0.75000 to 0.76500, saving model to vggface2.h5
# 100/100 - 35s - loss: 9.2172 - acc: 0.7431 - val_loss: 9.1737 - val_acc: 0.7650
# Epoch 29/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00029: val_acc did not improve from 0.76500
# 100/100 - 32s - loss: 9.1408 - acc: 0.7719 - val_loss: 9.1708 - val_acc: 0.7525
# Epoch 30/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00030: val_acc did not improve from 0.76500
# 100/100 - 33s - loss: 9.1000 - acc: 0.7481 - val_loss: 9.1340 - val_acc: 0.7475
# Epoch 31/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00031: val_acc improved from 0.76500 to 0.77625, saving model to vggface2.h5
# 100/100 - 35s - loss: 9.0565 - acc: 0.7400 - val_loss: 9.0392 - val_acc: 0.7763
# Epoch 32/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00032: val_acc did not improve from 0.77625
# 100/100 - 32s - loss: 9.0123 - acc: 0.7369 - val_loss: 9.0747 - val_acc: 0.7550
# Epoch 33/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00033: val_acc did not improve from 0.77625
# 100/100 - 33s - loss: 8.9256 - acc: 0.7481 - val_loss: 9.0159 - val_acc: 0.7538
# Epoch 34/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00034: val_acc did not improve from 0.77625
# 100/100 - 33s - loss: 8.8445 - acc: 0.7756 - val_loss: 8.9883 - val_acc: 0.7375
# Epoch 35/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00035: val_acc did not improve from 0.77625
# 100/100 - 33s - loss: 8.7932 - acc: 0.7656 - val_loss: 8.8617 - val_acc: 0.7575
# Epoch 36/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00036: val_acc did not improve from 0.77625
# 100/100 - 33s - loss: 8.7119 - acc: 0.7763 - val_loss: 8.7303 - val_acc: 0.7613
# Epoch 37/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00037: val_acc did not improve from 0.77625
# 100/100 - 33s - loss: 8.6390 - acc: 0.7731 - val_loss: 8.7251 - val_acc: 0.7625
# Epoch 38/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00038: val_acc did not improve from 0.77625
# 100/100 - 33s - loss: 8.5910 - acc: 0.7675 - val_loss: 8.6579 - val_acc: 0.7300
# Epoch 39/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00039: val_acc did not improve from 0.77625
# 100/100 - 33s - loss: 8.5234 - acc: 0.7837 - val_loss: 8.5567 - val_acc: 0.7550
# Epoch 40/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00040: val_acc improved from 0.77625 to 0.79750, saving model to vggface2.h5
# 100/100 - 35s - loss: 8.4330 - acc: 0.7781 - val_loss: 8.4519 - val_acc: 0.7975
# Epoch 41/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00041: val_acc did not improve from 0.79750
# 100/100 - 32s - loss: 8.3582 - acc: 0.7969 - val_loss: 8.3960 - val_acc: 0.7663
# Epoch 42/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00042: val_acc did not improve from 0.79750
# 100/100 - 34s - loss: 8.3113 - acc: 0.7862 - val_loss: 8.3350 - val_acc: 0.7550
# Epoch 43/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00043: val_acc did not improve from 0.79750
# 100/100 - 33s - loss: 8.2166 - acc: 0.7819 - val_loss: 8.3274 - val_acc: 0.7625
# Epoch 44/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00044: val_acc did not improve from 0.79750
# 100/100 - 33s - loss: 8.1479 - acc: 0.7806 - val_loss: 8.1737 - val_acc: 0.7613
# Epoch 45/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00045: val_acc did not improve from 0.79750
# 100/100 - 34s - loss: 8.0329 - acc: 0.8019 - val_loss: 8.0507 - val_acc: 0.7788
# Epoch 46/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00046: val_acc did not improve from 0.79750
# 100/100 - 33s - loss: 7.9893 - acc: 0.7975 - val_loss: 7.9915 - val_acc: 0.7788
# Epoch 47/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00047: val_acc did not improve from 0.79750
# 100/100 - 33s - loss: 7.8857 - acc: 0.8044 - val_loss: 7.9075 - val_acc: 0.7912
# Epoch 48/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00048: val_acc did not improve from 0.79750
# 100/100 - 34s - loss: 7.8129 - acc: 0.7900 - val_loss: 7.9544 - val_acc: 0.7775
# Epoch 49/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00049: val_acc did not improve from 0.79750
# 100/100 - 33s - loss: 7.7319 - acc: 0.7944 - val_loss: 7.7453 - val_acc: 0.7900
# Epoch 50/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00050: val_acc did not improve from 0.79750
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 100/100 - 36s - loss: 7.6560 - acc: 0.7875 - val_loss: 7.6685 - val_acc: 0.7600

# %% [markdown]
# **Model 3/6**

# %%
def baseline_model3():

    input_1 = Input(shape=(224, 224, 3))
    input_2 = Input(shape=(224, 224, 3))

    base_model = VGGFace(model='resnet50', include_top=False)

    for x in base_model.layers[:-3]:
        x.trainable = True

    x1 = base_model(input_1)
    x2 = base_model(input_2)

    x1 = Concatenate(axis=-1)([GlobalMaxPool2D()(x1), GlobalAvgPool2D()(x1)])
    x2 = Concatenate(axis=-1)([GlobalMaxPool2D()(x2), GlobalAvgPool2D()(x2)])

    x3 = Subtract()([x1, x2])
    x3 = Multiply()([x3, x3])

    x = Add()([x1, x2])

    x = Concatenate(axis=-1)([x, x3])

    x = Dense(512, activation="relu",kernel_regularizer=regularizers.l2(0.01))(x)
    x = Dropout(0.5)(x)
    out = Dense(1, activation="sigmoid")(x)

    model = Model([input_1, input_2], out)

    model.compile(loss="binary_crossentropy", metrics=['acc'], optimizer=Adam(0.00001))

    model.summary()

    return model

# %%
file_path = "vggface3.h5"

checkpoint = ModelCheckpoint(file_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

reduce_on_plateau = ReduceLROnPlateau(monitor="val_acc", mode="max", factor=0.1, patience=10, verbose=1)

early_stop = EarlyStopping(monitor='loss', patience=5)

callbacks_list = [checkpoint, reduce_on_plateau, early_stop]

model3 = baseline_model3()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# vggface_resnet50 (Functional)   (None, None, None, 2 23561152    input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_4 (GlobalM (None, 2048)         0           vggface_resnet50[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 2048)         0           vggface_resnet50[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_5 (GlobalM (None, 2048)         0           vggface_resnet50[1][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 2048)         0           vggface_resnet50[1][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 4096)         0           global_max_pooling2d_4[0][0]
#                                                                  global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 4096)         0           global_max_pooling2d_5[0][0]
#                                                                  global_average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# subtract_3 (Subtract)           (None, 4096)         0           concatenate_6[0][0]
#                                                                  concatenate_7[0][0]
# __________________________________________________________________________________________________
# add_48 (Add)                    (None, 4096)         0           concatenate_6[0][0]
#                                                                  concatenate_7[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 4096)         0           subtract_3[0][0]
#                                                                  subtract_3[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 8192)         0           add_48[0][0]
#                                                                  multiply_5[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 512)          4194816     concatenate_8[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 512)          0           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            513         dropout_2[0][0]
# ==================================================================================================
# Total params: 27,756,481
# Trainable params: 27,703,361
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
model3.fit(gen(train, train_person_to_images_map, batch_size=16), use_multiprocessing=True,
                    validation_data=gen(val, val_person_to_images_map, batch_size=16), epochs=50, verbose=2,
                    workers=4, callbacks=callbacks_list, steps_per_epoch=100, validation_steps=50)
# Out:
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# Epoch 1/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# Epoch 00001: val_acc improved from -inf to 0.55000, saving model to vggface3.h5
# 100/100 - 58s - loss: 14.7935 - acc: 0.5350 - val_loss: 13.6909 - val_acc: 0.5500
# Epoch 2/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00002: val_acc improved from 0.55000 to 0.58000, saving model to vggface3.h5
# 100/100 - 35s - loss: 12.5616 - acc: 0.5825 - val_loss: 12.5986 - val_acc: 0.5800
# Epoch 3/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00003: val_acc did not improve from 0.58000
# 100/100 - 33s - loss: 11.7204 - acc: 0.5938 - val_loss: 12.3995 - val_acc: 0.5362
# Epoch 4/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00004: val_acc improved from 0.58000 to 0.61000, saving model to vggface3.h5
# 100/100 - 36s - loss: 11.0119 - acc: 0.6100 - val_loss: 10.6622 - val_acc: 0.6100
# Epoch 5/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00005: val_acc improved from 0.61000 to 0.64250, saving model to vggface3.h5
# 100/100 - 35s - loss: 10.5105 - acc: 0.6175 - val_loss: 10.5323 - val_acc: 0.6425
# Epoch 6/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00006: val_acc did not improve from 0.64250
# 100/100 - 33s - loss: 10.2999 - acc: 0.6288 - val_loss: 10.3969 - val_acc: 0.6250
# Epoch 7/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00007: val_acc did not improve from 0.64250
# 100/100 - 34s - loss: 10.1652 - acc: 0.6594 - val_loss: 11.7374 - val_acc: 0.6237
# Epoch 8/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00008: val_acc improved from 0.64250 to 0.65000, saving model to vggface3.h5
# 100/100 - 36s - loss: 10.0894 - acc: 0.6375 - val_loss: 11.1556 - val_acc: 0.6500
# Epoch 9/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00009: val_acc improved from 0.65000 to 0.67000, saving model to vggface3.h5
# 100/100 - 35s - loss: 9.9398 - acc: 0.6969 - val_loss: 10.4332 - val_acc: 0.6700
# Epoch 10/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00010: val_acc did not improve from 0.67000
# 100/100 - 33s - loss: 9.9495 - acc: 0.6469 - val_loss: 10.5921 - val_acc: 0.6525
# Epoch 11/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00011: val_acc improved from 0.67000 to 0.71250, saving model to vggface3.h5
# 100/100 - 36s - loss: 9.8640 - acc: 0.6725 - val_loss: 11.4159 - val_acc: 0.7125
# Epoch 12/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00012: val_acc did not improve from 0.71250
# 100/100 - 33s - loss: 9.7750 - acc: 0.7006 - val_loss: 10.2799 - val_acc: 0.6913
# Epoch 13/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00013: val_acc did not improve from 0.71250
# 100/100 - 34s - loss: 9.7426 - acc: 0.7006 - val_loss: 11.4774 - val_acc: 0.6913
# Epoch 14/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00014: val_acc did not improve from 0.71250
# 100/100 - 33s - loss: 9.6645 - acc: 0.7206 - val_loss: 11.5075 - val_acc: 0.7113
# Epoch 15/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00015: val_acc improved from 0.71250 to 0.72500, saving model to vggface3.h5
# 100/100 - 36s - loss: 9.6132 - acc: 0.7188 - val_loss: 10.2008 - val_acc: 0.7250
# Epoch 16/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00016: val_acc did not improve from 0.72500
# 100/100 - 33s - loss: 9.5481 - acc: 0.7381 - val_loss: 10.1700 - val_acc: 0.7025
# Epoch 17/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00017: val_acc did not improve from 0.72500
# 100/100 - 34s - loss: 9.5095 - acc: 0.7269 - val_loss: 13.7415 - val_acc: 0.7237
# Epoch 18/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00018: val_acc did not improve from 0.72500
# 100/100 - 34s - loss: 9.4455 - acc: 0.7200 - val_loss: 9.4484 - val_acc: 0.7038
# Epoch 19/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00019: val_acc improved from 0.72500 to 0.72875, saving model to vggface3.h5
# 100/100 - 36s - loss: 9.4019 - acc: 0.7287 - val_loss: 11.2078 - val_acc: 0.7287
# Epoch 20/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00020: val_acc improved from 0.72875 to 0.73750, saving model to vggface3.h5
# 100/100 - 35s - loss: 9.3260 - acc: 0.7381 - val_loss: 9.6214 - val_acc: 0.7375
# Epoch 21/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00021: val_acc did not improve from 0.73750
# 100/100 - 33s - loss: 9.2612 - acc: 0.7500 - val_loss: 11.3794 - val_acc: 0.6925
# Epoch 22/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00022: val_acc did not improve from 0.73750
# 100/100 - 34s - loss: 9.2208 - acc: 0.7231 - val_loss: 9.9904 - val_acc: 0.7150
# Epoch 23/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00023: val_acc did not improve from 0.73750
# 100/100 - 34s - loss: 9.1660 - acc: 0.7444 - val_loss: 10.2178 - val_acc: 0.7212
# Epoch 24/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00024: val_acc improved from 0.73750 to 0.74375, saving model to vggface3.h5
# 100/100 - 36s - loss: 9.1185 - acc: 0.7362 - val_loss: 9.6869 - val_acc: 0.7437
# Epoch 25/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00025: val_acc did not improve from 0.74375
# 100/100 - 33s - loss: 9.0193 - acc: 0.7444 - val_loss: 9.3643 - val_acc: 0.7300
# Epoch 26/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00026: val_acc did not improve from 0.74375
# 100/100 - 34s - loss: 8.9411 - acc: 0.7619 - val_loss: 10.4524 - val_acc: 0.7100
# Epoch 27/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00027: val_acc improved from 0.74375 to 0.75375, saving model to vggface3.h5
# 100/100 - 36s - loss: 8.8806 - acc: 0.7719 - val_loss: 10.3081 - val_acc: 0.7538
# Epoch 28/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00028: val_acc did not improve from 0.75375
# 100/100 - 33s - loss: 8.8078 - acc: 0.7656 - val_loss: 9.6470 - val_acc: 0.7375
# Epoch 29/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00029: val_acc did not improve from 0.75375
# 100/100 - 33s - loss: 8.7402 - acc: 0.7631 - val_loss: 9.8119 - val_acc: 0.7250
# Epoch 30/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00030: val_acc improved from 0.75375 to 0.78750, saving model to vggface3.h5
# 100/100 - 36s - loss: 8.7153 - acc: 0.7262 - val_loss: 9.4355 - val_acc: 0.7875
# Epoch 31/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00031: val_acc did not improve from 0.78750
# 100/100 - 33s - loss: 8.6100 - acc: 0.7688 - val_loss: 9.3176 - val_acc: 0.7525
# Epoch 32/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00032: val_acc did not improve from 0.78750
# 100/100 - 34s - loss: 8.5503 - acc: 0.7550 - val_loss: 11.2640 - val_acc: 0.7563
# Epoch 33/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00033: val_acc did not improve from 0.78750
# 100/100 - 34s - loss: 8.4607 - acc: 0.7694 - val_loss: 14.5686 - val_acc: 0.7525
# Epoch 34/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00034: val_acc did not improve from 0.78750
# 100/100 - 34s - loss: 8.3931 - acc: 0.7706 - val_loss: 12.0549 - val_acc: 0.7237
# Epoch 35/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00035: val_acc did not improve from 0.78750
# 100/100 - 34s - loss: 8.3360 - acc: 0.7619 - val_loss: 8.6719 - val_acc: 0.7375
# Epoch 36/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00036: val_acc did not improve from 0.78750
# 100/100 - 34s - loss: 8.2523 - acc: 0.7688 - val_loss: 8.4077 - val_acc: 0.7675
# Epoch 37/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00037: val_acc did not improve from 0.78750
# 100/100 - 34s - loss: 8.1739 - acc: 0.7681 - val_loss: 8.7207 - val_acc: 0.7538
# Epoch 38/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00038: val_acc did not improve from 0.78750
# 100/100 - 34s - loss: 8.0925 - acc: 0.7831 - val_loss: 8.2633 - val_acc: 0.7513
# Epoch 39/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00039: val_acc did not improve from 0.78750
# 100/100 - 33s - loss: 7.9972 - acc: 0.8012 - val_loss: 8.9147 - val_acc: 0.7350
# Epoch 40/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00040: val_acc did not improve from 0.78750
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 100/100 - 37s - loss: 7.9356 - acc: 0.7887 - val_loss: 8.8165 - val_acc: 0.7613
# Epoch 41/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00041: val_acc did not improve from 0.78750
# 100/100 - 33s - loss: 7.8897 - acc: 0.7812 - val_loss: 7.9271 - val_acc: 0.7713
# Epoch 42/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00042: val_acc did not improve from 0.78750
# 100/100 - 34s - loss: 7.8474 - acc: 0.7950 - val_loss: 8.1232 - val_acc: 0.7713
# Epoch 43/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00043: val_acc did not improve from 0.78750
# 100/100 - 33s - loss: 7.8791 - acc: 0.7763 - val_loss: 8.2569 - val_acc: 0.7575
# Epoch 44/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00044: val_acc did not improve from 0.78750
# 100/100 - 34s - loss: 7.8223 - acc: 0.8156 - val_loss: 8.8092 - val_acc: 0.7425
# Epoch 45/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00045: val_acc did not improve from 0.78750
# 100/100 - 34s - loss: 7.8149 - acc: 0.8094 - val_loss: 8.0620 - val_acc: 0.7487
# Epoch 46/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00046: val_acc did not improve from 0.78750
# 100/100 - 34s - loss: 7.8362 - acc: 0.7800 - val_loss: 8.1369 - val_acc: 0.7487
# Epoch 47/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00047: val_acc did not improve from 0.78750
# 100/100 - 34s - loss: 7.8034 - acc: 0.7962 - val_loss: 8.3126 - val_acc: 0.7675
# Epoch 48/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00048: val_acc did not improve from 0.78750
# 100/100 - 34s - loss: 7.7827 - acc: 0.8081 - val_loss: 8.2734 - val_acc: 0.7525
# Epoch 49/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00049: val_acc did not improve from 0.78750
# 100/100 - 34s - loss: 7.7944 - acc: 0.7856 - val_loss: 8.2132 - val_acc: 0.7513
# Epoch 50/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00050: val_acc improved from 0.78750 to 0.79875, saving model to vggface3.h5
# 100/100 - 36s - loss: 7.7640 - acc: 0.8062 - val_loss: 7.9035 - val_acc: 0.7987

# %% [markdown]
# **Model 4/6**

# %%
def baseline_model4():

    input_1 = Input(shape=(224, 224, 3))
    input_2 = Input(shape=(224, 224, 3))

    base_model = VGGFace(model='resnet50', include_top=False)

    for x in base_model.layers[:-3]:
        x.trainable = True

    x1 = base_model(input_1)
    x2 = base_model(input_2)

    x1 = Concatenate(axis=-1)([GlobalMaxPool2D()(x1), GlobalAvgPool2D()(x1)])
    x2 = Concatenate(axis=-1)([GlobalMaxPool2D()(x2), GlobalAvgPool2D()(x2)])

    x1_2 = Multiply()([x1, x1])
    x2_2 = Multiply()([x2, x2])

    x3 = Subtract()([x1_2, x2_2])

    x = Multiply()([x1, x2])

    x = Concatenate(axis=-1)([x, x3])

    x = Dense(512, activation="relu",kernel_regularizer=regularizers.l2(0.01))(x)
    x = Dropout(0.5)(x)
    out = Dense(1, activation="sigmoid")(x)

    model = Model([input_1, input_2], out)

    model.compile(loss="binary_crossentropy", metrics=['acc'], optimizer=Adam(0.00001))

    model.summary()

    return model

# %%
file_path = "vggface4.h5"

checkpoint = ModelCheckpoint(file_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

reduce_on_plateau = ReduceLROnPlateau(monitor="val_acc", mode="max", factor=0.1, patience=10, verbose=1)

early_stop = EarlyStopping(monitor='loss', patience=5)

callbacks_list = [checkpoint, reduce_on_plateau, early_stop]

model4 = baseline_model4()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_10 (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# vggface_resnet50 (Functional)   (None, None, None, 2 23561152    input_10[0][0]
#                                                                  input_11[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_6 (GlobalM (None, 2048)         0           vggface_resnet50[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 2048)         0           vggface_resnet50[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_7 (GlobalM (None, 2048)         0           vggface_resnet50[1][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_7 (Glo (None, 2048)         0           vggface_resnet50[1][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 4096)         0           global_max_pooling2d_6[0][0]
#                                                                  global_average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 4096)         0           global_max_pooling2d_7[0][0]
#                                                                  global_average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 4096)         0           concatenate_9[0][0]
#                                                                  concatenate_9[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 4096)         0           concatenate_10[0][0]
#                                                                  concatenate_10[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 4096)         0           concatenate_9[0][0]
#                                                                  concatenate_10[0][0]
# __________________________________________________________________________________________________
# subtract_4 (Subtract)           (None, 4096)         0           multiply_6[0][0]
#                                                                  multiply_7[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 8192)         0           multiply_8[0][0]
#                                                                  subtract_4[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 512)          4194816     concatenate_11[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 512)          0           dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1)            513         dropout_3[0][0]
# ==================================================================================================
# Total params: 27,756,481
# Trainable params: 27,703,361
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
model4.fit(gen(train, train_person_to_images_map, batch_size=16), use_multiprocessing=True,
                    validation_data=gen(val, val_person_to_images_map, batch_size=16), epochs=50, verbose=2,
                    workers=4, callbacks=callbacks_list, steps_per_epoch=100, validation_steps=50)
# Out:
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# Epoch 1/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# Epoch 00001: val_acc improved from -inf to 0.56250, saving model to vggface4.h5
# 100/100 - 63s - loss: 16.3986 - acc: 0.5069 - val_loss: 15.1887 - val_acc: 0.5625
# Epoch 2/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00002: val_acc improved from 0.56250 to 0.57875, saving model to vggface4.h5
# 100/100 - 36s - loss: 13.7753 - acc: 0.5694 - val_loss: 12.7614 - val_acc: 0.5788
# Epoch 3/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00003: val_acc improved from 0.57875 to 0.61375, saving model to vggface4.h5
# 100/100 - 36s - loss: 11.9726 - acc: 0.5987 - val_loss: 11.5657 - val_acc: 0.6137
# Epoch 4/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00004: val_acc did not improve from 0.61375
# 100/100 - 33s - loss: 10.9366 - acc: 0.6081 - val_loss: 10.8086 - val_acc: 0.6112
# Epoch 5/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00005: val_acc improved from 0.61375 to 0.62625, saving model to vggface4.h5
# 100/100 - 36s - loss: 10.6625 - acc: 0.5956 - val_loss: 10.4303 - val_acc: 0.6263
# Epoch 6/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00006: val_acc improved from 0.62625 to 0.65000, saving model to vggface4.h5
# 100/100 - 35s - loss: 10.4009 - acc: 0.6350 - val_loss: 10.4274 - val_acc: 0.6500
# Epoch 7/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00007: val_acc did not improve from 0.65000
# 100/100 - 34s - loss: 10.2217 - acc: 0.6231 - val_loss: 10.1979 - val_acc: 0.6150
# Epoch 8/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00008: val_acc improved from 0.65000 to 0.66250, saving model to vggface4.h5
# 100/100 - 37s - loss: 10.0770 - acc: 0.6344 - val_loss: 10.1696 - val_acc: 0.6625
# Epoch 9/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00009: val_acc improved from 0.66250 to 0.67250, saving model to vggface4.h5
# 100/100 - 35s - loss: 9.9779 - acc: 0.6569 - val_loss: 9.9734 - val_acc: 0.6725
# Epoch 10/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00010: val_acc did not improve from 0.67250
# 100/100 - 33s - loss: 9.8943 - acc: 0.6637 - val_loss: 9.9049 - val_acc: 0.6687
# Epoch 11/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00011: val_acc improved from 0.67250 to 0.69750, saving model to vggface4.h5
# 100/100 - 36s - loss: 9.7832 - acc: 0.6944 - val_loss: 9.8076 - val_acc: 0.6975
# Epoch 12/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00012: val_acc did not improve from 0.69750
# 100/100 - 33s - loss: 9.7479 - acc: 0.6675 - val_loss: 9.9297 - val_acc: 0.6513
# Epoch 13/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00013: val_acc did not improve from 0.69750
# 100/100 - 35s - loss: 9.6853 - acc: 0.6825 - val_loss: 9.7321 - val_acc: 0.6963
# Epoch 14/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00014: val_acc improved from 0.69750 to 0.73500, saving model to vggface4.h5
# 100/100 - 35s - loss: 9.5828 - acc: 0.7281 - val_loss: 9.5844 - val_acc: 0.7350
# Epoch 15/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00015: val_acc did not improve from 0.73500
# 100/100 - 33s - loss: 9.5238 - acc: 0.7044 - val_loss: 9.6323 - val_acc: 0.6900
# Epoch 16/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00016: val_acc did not improve from 0.73500
# 100/100 - 34s - loss: 9.4619 - acc: 0.7200 - val_loss: 9.5884 - val_acc: 0.6888
# Epoch 17/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00017: val_acc did not improve from 0.73500
# 100/100 - 34s - loss: 9.4110 - acc: 0.7156 - val_loss: 9.4354 - val_acc: 0.7038
# Epoch 18/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00018: val_acc improved from 0.73500 to 0.74375, saving model to vggface4.h5
# 100/100 - 36s - loss: 9.3056 - acc: 0.7406 - val_loss: 9.3155 - val_acc: 0.7437
# Epoch 19/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00019: val_acc improved from 0.74375 to 0.74500, saving model to vggface4.h5
# 100/100 - 35s - loss: 9.2657 - acc: 0.7275 - val_loss: 9.2408 - val_acc: 0.7450
# Epoch 20/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00020: val_acc did not improve from 0.74500
# 100/100 - 33s - loss: 9.1681 - acc: 0.7462 - val_loss: 9.2008 - val_acc: 0.7200
# Epoch 21/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00021: val_acc did not improve from 0.74500
# 100/100 - 34s - loss: 9.1116 - acc: 0.7462 - val_loss: 9.2494 - val_acc: 0.7325
# Epoch 22/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00022: val_acc did not improve from 0.74500
# 100/100 - 34s - loss: 9.0137 - acc: 0.7669 - val_loss: 9.1056 - val_acc: 0.7437
# Epoch 23/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00023: val_acc did not improve from 0.74500
# 100/100 - 34s - loss: 8.9962 - acc: 0.7406 - val_loss: 9.0567 - val_acc: 0.7088
# Epoch 24/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00024: val_acc did not improve from 0.74500
# 100/100 - 34s - loss: 8.8754 - acc: 0.7638 - val_loss: 8.9396 - val_acc: 0.7362
# Epoch 25/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00025: val_acc improved from 0.74500 to 0.76750, saving model to vggface4.h5
# 100/100 - 36s - loss: 8.8171 - acc: 0.7681 - val_loss: 8.8214 - val_acc: 0.7675
# Epoch 26/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00026: val_acc did not improve from 0.76750
# 100/100 - 33s - loss: 8.7214 - acc: 0.7731 - val_loss: 8.7630 - val_acc: 0.7275
# Epoch 27/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00027: val_acc did not improve from 0.76750
# 100/100 - 34s - loss: 8.6506 - acc: 0.7738 - val_loss: 8.7521 - val_acc: 0.7563
# Epoch 28/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00028: val_acc improved from 0.76750 to 0.77125, saving model to vggface4.h5
# 100/100 - 36s - loss: 8.5951 - acc: 0.7563 - val_loss: 8.5695 - val_acc: 0.7713
# Epoch 29/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00029: val_acc did not improve from 0.77125
# 100/100 - 33s - loss: 8.5088 - acc: 0.7781 - val_loss: 8.5494 - val_acc: 0.7563
# Epoch 30/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00030: val_acc improved from 0.77125 to 0.77500, saving model to vggface4.h5
# 100/100 - 35s - loss: 8.4120 - acc: 0.7812 - val_loss: 8.4089 - val_acc: 0.7750
# Epoch 31/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00031: val_acc did not improve from 0.77500
# 100/100 - 33s - loss: 8.3377 - acc: 0.7906 - val_loss: 8.3500 - val_acc: 0.7650
# Epoch 32/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00032: val_acc improved from 0.77500 to 0.77750, saving model to vggface4.h5
# 100/100 - 35s - loss: 8.2579 - acc: 0.7925 - val_loss: 8.2717 - val_acc: 0.7775
# Epoch 33/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00033: val_acc improved from 0.77750 to 0.81625, saving model to vggface4.h5
# 100/100 - 35s - loss: 8.1703 - acc: 0.7956 - val_loss: 8.1245 - val_acc: 0.8163
# Epoch 34/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00034: val_acc did not improve from 0.81625
# 100/100 - 33s - loss: 8.1099 - acc: 0.7856 - val_loss: 8.0570 - val_acc: 0.7962
# Epoch 35/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00035: val_acc did not improve from 0.81625
# 100/100 - 33s - loss: 8.0174 - acc: 0.8006 - val_loss: 8.0163 - val_acc: 0.7713
# Epoch 36/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00036: val_acc did not improve from 0.81625
# 100/100 - 34s - loss: 7.9307 - acc: 0.8094 - val_loss: 7.9765 - val_acc: 0.8000
# Epoch 37/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00037: val_acc did not improve from 0.81625
# 100/100 - 34s - loss: 7.8554 - acc: 0.7994 - val_loss: 7.8325 - val_acc: 0.7975
# Epoch 38/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00038: val_acc improved from 0.81625 to 0.82000, saving model to vggface4.h5
# 100/100 - 36s - loss: 7.7509 - acc: 0.7950 - val_loss: 7.7416 - val_acc: 0.8200
# Epoch 39/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00039: val_acc did not improve from 0.82000
# 100/100 - 33s - loss: 7.6664 - acc: 0.8138 - val_loss: 7.8743 - val_acc: 0.7738
# Epoch 40/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00040: val_acc did not improve from 0.82000
# 100/100 - 34s - loss: 7.5847 - acc: 0.7994 - val_loss: 7.5914 - val_acc: 0.8000
# Epoch 41/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00041: val_acc did not improve from 0.82000
# 100/100 - 34s - loss: 7.5021 - acc: 0.8087 - val_loss: 7.6226 - val_acc: 0.7862
# Epoch 42/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00042: val_acc did not improve from 0.82000
# 100/100 - 34s - loss: 7.4213 - acc: 0.8025 - val_loss: 7.4560 - val_acc: 0.7862
# Epoch 43/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00043: val_acc did not improve from 0.82000
# 100/100 - 35s - loss: 7.3274 - acc: 0.8075 - val_loss: 7.3726 - val_acc: 0.7788
# Epoch 44/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00044: val_acc did not improve from 0.82000
# 100/100 - 34s - loss: 7.2388 - acc: 0.8250 - val_loss: 7.2580 - val_acc: 0.8050
# Epoch 45/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00045: val_acc did not improve from 0.82000
# 100/100 - 33s - loss: 7.1402 - acc: 0.8181 - val_loss: 7.1374 - val_acc: 0.7987
# Epoch 46/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00046: val_acc improved from 0.82000 to 0.82625, saving model to vggface4.h5
# 100/100 - 36s - loss: 7.0396 - acc: 0.8319 - val_loss: 7.0236 - val_acc: 0.8263
# Epoch 47/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00047: val_acc did not improve from 0.82625
# 100/100 - 33s - loss: 6.9716 - acc: 0.8213 - val_loss: 6.9705 - val_acc: 0.8075
# Epoch 48/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00048: val_acc improved from 0.82625 to 0.83125, saving model to vggface4.h5
# 100/100 - 36s - loss: 6.8766 - acc: 0.8225 - val_loss: 6.8237 - val_acc: 0.8313
# Epoch 49/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00049: val_acc did not improve from 0.83125
# 100/100 - 33s - loss: 6.7716 - acc: 0.8350 - val_loss: 6.8632 - val_acc: 0.8125
# Epoch 50/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00050: val_acc did not improve from 0.83125
# 100/100 - 34s - loss: 6.6966 - acc: 0.8225 - val_loss: 6.7394 - val_acc: 0.7962

# %% [markdown]
# **Model 5/6**

# %%
def baseline_model5():

    input_1 = Input(shape=(224, 224, 3))
    input_2 = Input(shape=(224, 224, 3))

    base_model = VGGFace(model='resnet50', include_top=False)

    for x in base_model.layers[:-3]:
        x.trainable = True

    x1 = base_model(input_1)
    x2 = base_model(input_2)

    x1 = Concatenate(axis=-1)([GlobalMaxPool2D()(x1), GlobalAvgPool2D()(x1)])
    x2 = Concatenate(axis=-1)([GlobalMaxPool2D()(x2), GlobalAvgPool2D()(x2)])

    x1_2 = Multiply()([x1, x1])
    x2_2 = Multiply()([x2, x2])

    x3 = Subtract()([x1_2, x2_2])

    x = Add()([x1, x2])

    x = Concatenate(axis=-1)([x, x3])

    x = Dense(512, activation="relu",kernel_regularizer=regularizers.l2(0.01))(x)
    x = Dropout(0.5)(x)
    out = Dense(1, activation="sigmoid")(x)

    model = Model([input_1, input_2], out)

    model.compile(loss="binary_crossentropy", metrics=['acc'], optimizer=Adam(0.00001))

    model.summary()

    return model

# %%
file_path = "vggface5.h5"

checkpoint = ModelCheckpoint(file_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

reduce_on_plateau = ReduceLROnPlateau(monitor="val_acc", mode="max", factor=0.1, patience=10, verbose=1)

early_stop = EarlyStopping(monitor='loss', patience=5)

callbacks_list = [checkpoint, reduce_on_plateau, early_stop]

model5 = baseline_model5()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_13 (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# input_14 (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# vggface_resnet50 (Functional)   (None, None, None, 2 23561152    input_13[0][0]
#                                                                  input_14[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_8 (GlobalM (None, 2048)         0           vggface_resnet50[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_8 (Glo (None, 2048)         0           vggface_resnet50[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_9 (GlobalM (None, 2048)         0           vggface_resnet50[1][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_9 (Glo (None, 2048)         0           vggface_resnet50[1][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 4096)         0           global_max_pooling2d_8[0][0]
#                                                                  global_average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 4096)         0           global_max_pooling2d_9[0][0]
#                                                                  global_average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 4096)         0           concatenate_12[0][0]
#                                                                  concatenate_12[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 4096)         0           concatenate_13[0][0]
#                                                                  concatenate_13[0][0]
# __________________________________________________________________________________________________
# add_81 (Add)                    (None, 4096)         0           concatenate_12[0][0]
#                                                                  concatenate_13[0][0]
# __________________________________________________________________________________________________
# subtract_5 (Subtract)           (None, 4096)         0           multiply_9[0][0]
#                                                                  multiply_10[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 8192)         0           add_81[0][0]
#                                                                  subtract_5[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 512)          4194816     concatenate_14[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 512)          0           dense_8[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 1)            513         dropout_4[0][0]
# ==================================================================================================
# Total params: 27,756,481
# Trainable params: 27,703,361
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
model5.fit(gen(train, train_person_to_images_map, batch_size=16), use_multiprocessing=True,
                    validation_data=gen(val, val_person_to_images_map, batch_size=16), epochs=50, verbose=2,
                    workers=4, callbacks=callbacks_list, steps_per_epoch=100, validation_steps=50)
# Out:
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# Epoch 1/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# Epoch 00001: val_acc improved from -inf to 0.52375, saving model to vggface5.h5
# 100/100 - 67s - loss: 15.7264 - acc: 0.5113 - val_loss: 14.0345 - val_acc: 0.5238
# Epoch 2/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00002: val_acc improved from 0.52375 to 0.57875, saving model to vggface5.h5
# 100/100 - 36s - loss: 13.4476 - acc: 0.5650 - val_loss: 12.6244 - val_acc: 0.5788
# Epoch 3/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00003: val_acc improved from 0.57875 to 0.62250, saving model to vggface5.h5
# 100/100 - 36s - loss: 11.9635 - acc: 0.5619 - val_loss: 11.1103 - val_acc: 0.6225
# Epoch 4/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00004: val_acc did not improve from 0.62250
# 100/100 - 34s - loss: 11.0286 - acc: 0.5981 - val_loss: 10.6914 - val_acc: 0.5962
# Epoch 5/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00005: val_acc did not improve from 0.62250
# 100/100 - 36s - loss: 10.5653 - acc: 0.5900 - val_loss: 10.4195 - val_acc: 0.6087
# Epoch 6/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00006: val_acc improved from 0.62250 to 0.64250, saving model to vggface5.h5
# 100/100 - 38s - loss: 10.2381 - acc: 0.6325 - val_loss: 10.2028 - val_acc: 0.6425
# Epoch 7/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00007: val_acc did not improve from 0.64250
# 100/100 - 34s - loss: 10.1314 - acc: 0.6175 - val_loss: 10.0207 - val_acc: 0.6400
# Epoch 8/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00008: val_acc did not improve from 0.64250
# 100/100 - 35s - loss: 10.0458 - acc: 0.6181 - val_loss: 10.0548 - val_acc: 0.6175
# Epoch 9/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00009: val_acc improved from 0.64250 to 0.66750, saving model to vggface5.h5
# 100/100 - 37s - loss: 9.9400 - acc: 0.6369 - val_loss: 9.8872 - val_acc: 0.6675
# Epoch 10/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00010: val_acc did not improve from 0.66750
# 100/100 - 34s - loss: 9.8489 - acc: 0.6700 - val_loss: 9.8774 - val_acc: 0.6500
# Epoch 11/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00011: val_acc improved from 0.66750 to 0.67375, saving model to vggface5.h5
# 100/100 - 37s - loss: 9.8086 - acc: 0.6594 - val_loss: 9.7705 - val_acc: 0.6737
# Epoch 12/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00012: val_acc improved from 0.67375 to 0.67625, saving model to vggface5.h5
# 100/100 - 36s - loss: 9.7176 - acc: 0.6656 - val_loss: 9.7150 - val_acc: 0.6762
# Epoch 13/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00013: val_acc improved from 0.67625 to 0.69000, saving model to vggface5.h5
# 100/100 - 36s - loss: 9.6469 - acc: 0.6931 - val_loss: 9.6227 - val_acc: 0.6900
# Epoch 14/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00014: val_acc did not improve from 0.69000
# 100/100 - 34s - loss: 9.6048 - acc: 0.6913 - val_loss: 9.6176 - val_acc: 0.6325
# Epoch 15/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00015: val_acc did not improve from 0.69000
# 100/100 - 34s - loss: 9.5324 - acc: 0.6881 - val_loss: 9.5866 - val_acc: 0.6513
# Epoch 16/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00016: val_acc did not improve from 0.69000
# 100/100 - 34s - loss: 9.4887 - acc: 0.6700 - val_loss: 9.5249 - val_acc: 0.6762
# Epoch 17/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00017: val_acc did not improve from 0.69000
# 100/100 - 35s - loss: 9.4173 - acc: 0.6819 - val_loss: 9.4908 - val_acc: 0.6862
# Epoch 18/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00018: val_acc did not improve from 0.69000
# 100/100 - 34s - loss: 9.3405 - acc: 0.7056 - val_loss: 9.3522 - val_acc: 0.6900
# Epoch 19/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00019: val_acc did not improve from 0.69000
# 100/100 - 34s - loss: 9.2784 - acc: 0.7063 - val_loss: 9.3116 - val_acc: 0.6800
# Epoch 20/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00020: val_acc did not improve from 0.69000
# 100/100 - 34s - loss: 9.2135 - acc: 0.7144 - val_loss: 9.2597 - val_acc: 0.6513
# Epoch 21/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00021: val_acc did not improve from 0.69000
# 100/100 - 34s - loss: 9.1611 - acc: 0.6881 - val_loss: 9.1629 - val_acc: 0.6888
# Epoch 22/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00022: val_acc did not improve from 0.69000
# 100/100 - 34s - loss: 9.0801 - acc: 0.7206 - val_loss: 9.1086 - val_acc: 0.6888
# Epoch 23/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00023: val_acc improved from 0.69000 to 0.70750, saving model to vggface5.h5
# 100/100 - 37s - loss: 9.0195 - acc: 0.7163 - val_loss: 9.0503 - val_acc: 0.7075
# Epoch 24/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00024: val_acc improved from 0.70750 to 0.71250, saving model to vggface5.h5
# 100/100 - 36s - loss: 8.9774 - acc: 0.7025 - val_loss: 8.9387 - val_acc: 0.7125
# Epoch 25/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00025: val_acc did not improve from 0.71250
# 100/100 - 33s - loss: 8.8693 - acc: 0.7331 - val_loss: 8.9558 - val_acc: 0.6875
# Epoch 26/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00026: val_acc improved from 0.71250 to 0.73125, saving model to vggface5.h5
# 100/100 - 37s - loss: 8.7925 - acc: 0.7444 - val_loss: 8.8291 - val_acc: 0.7312
# Epoch 27/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00027: val_acc did not improve from 0.73125
# 100/100 - 33s - loss: 8.7541 - acc: 0.7081 - val_loss: 8.7721 - val_acc: 0.7163
# Epoch 28/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00028: val_acc improved from 0.73125 to 0.73875, saving model to vggface5.h5
# 100/100 - 36s - loss: 8.6554 - acc: 0.7400 - val_loss: 8.6589 - val_acc: 0.7387
# Epoch 29/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00029: val_acc did not improve from 0.73875
# 100/100 - 34s - loss: 8.5912 - acc: 0.7456 - val_loss: 8.5932 - val_acc: 0.7312
# Epoch 30/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00030: val_acc did not improve from 0.73875
# 100/100 - 34s - loss: 8.5019 - acc: 0.7581 - val_loss: 8.5543 - val_acc: 0.7050
# Epoch 31/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00031: val_acc improved from 0.73875 to 0.74625, saving model to vggface5.h5
# 100/100 - 37s - loss: 8.4332 - acc: 0.7500 - val_loss: 8.4656 - val_acc: 0.7462
# Epoch 32/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00032: val_acc improved from 0.74625 to 0.78375, saving model to vggface5.h5
# 100/100 - 35s - loss: 8.3743 - acc: 0.7456 - val_loss: 8.3452 - val_acc: 0.7837
# Epoch 33/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00033: val_acc did not improve from 0.78375
# 100/100 - 34s - loss: 8.2469 - acc: 0.7819 - val_loss: 8.3547 - val_acc: 0.7462
# Epoch 34/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00034: val_acc did not improve from 0.78375
# 100/100 - 35s - loss: 8.2028 - acc: 0.7588 - val_loss: 8.2631 - val_acc: 0.7462
# Epoch 35/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00035: val_acc did not improve from 0.78375
# 100/100 - 35s - loss: 8.1165 - acc: 0.7625 - val_loss: 8.1318 - val_acc: 0.7700
# Epoch 36/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00036: val_acc did not improve from 0.78375
# 100/100 - 35s - loss: 8.0291 - acc: 0.7850 - val_loss: 8.1062 - val_acc: 0.7400
# Epoch 37/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00037: val_acc did not improve from 0.78375
# 100/100 - 34s - loss: 7.9630 - acc: 0.7850 - val_loss: 8.0603 - val_acc: 0.7300
# Epoch 38/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00038: val_acc did not improve from 0.78375
# 100/100 - 35s - loss: 7.8768 - acc: 0.7856 - val_loss: 7.9619 - val_acc: 0.7550
# Epoch 39/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00039: val_acc improved from 0.78375 to 0.79250, saving model to vggface5.h5
# 100/100 - 36s - loss: 7.7985 - acc: 0.7925 - val_loss: 7.8690 - val_acc: 0.7925
# Epoch 40/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00040: val_acc did not improve from 0.79250
# 100/100 - 34s - loss: 7.7170 - acc: 0.7844 - val_loss: 7.8737 - val_acc: 0.7538
# Epoch 41/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00041: val_acc did not improve from 0.79250
# 100/100 - 35s - loss: 7.6445 - acc: 0.7931 - val_loss: 7.8416 - val_acc: 0.7525
# Epoch 42/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00042: val_acc did not improve from 0.79250
# 100/100 - 35s - loss: 7.5589 - acc: 0.8056 - val_loss: 7.6821 - val_acc: 0.7538
# Epoch 43/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00043: val_acc improved from 0.79250 to 0.80500, saving model to vggface5.h5
# 100/100 - 37s - loss: 7.4935 - acc: 0.7881 - val_loss: 7.5230 - val_acc: 0.8050
# Epoch 44/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00044: val_acc did not improve from 0.80500
# 100/100 - 33s - loss: 7.4061 - acc: 0.7894 - val_loss: 7.5841 - val_acc: 0.7688
# Epoch 45/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00045: val_acc did not improve from 0.80500
# 100/100 - 35s - loss: 7.3050 - acc: 0.8044 - val_loss: 7.4342 - val_acc: 0.7775
# Epoch 46/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00046: val_acc did not improve from 0.80500
# 100/100 - 35s - loss: 7.2416 - acc: 0.8037 - val_loss: 7.2936 - val_acc: 0.7575
# Epoch 47/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00047: val_acc did not improve from 0.80500
# 100/100 - 34s - loss: 7.1612 - acc: 0.7975 - val_loss: 7.2055 - val_acc: 0.7675
# Epoch 48/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00048: val_acc did not improve from 0.80500
# 100/100 - 34s - loss: 7.0656 - acc: 0.8125 - val_loss: 7.1506 - val_acc: 0.7563
# Epoch 49/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00049: val_acc did not improve from 0.80500
# 100/100 - 35s - loss: 7.0000 - acc: 0.8037 - val_loss: 7.0146 - val_acc: 0.7725
# Epoch 50/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00050: val_acc did not improve from 0.80500
# 100/100 - 34s - loss: 6.8846 - acc: 0.8069 - val_loss: 6.9089 - val_acc: 0.7875

# %% [markdown]
# **Model 6/6**

# %%
def baseline_model6():

    input_1 = Input(shape=(224, 224, 3))
    input_2 = Input(shape=(224, 224, 3))

    base_model = VGGFace(model='resnet50', include_top=False)

    for x in base_model.layers[:-3]:
        x.trainable = True

    x1 = base_model(input_1)
    x2 = base_model(input_2)

    x1 = Concatenate(axis=-1)([GlobalMaxPool2D()(x1), GlobalAvgPool2D()(x1)])
    x2 = Concatenate(axis=-1)([GlobalMaxPool2D()(x2), GlobalAvgPool2D()(x2)])

    x3 = Add()([x1, x2])

    x = Multiply()([x1, x2])

    x = Concatenate(axis=-1)([x, x3])

    x = Dense(512, activation="relu",kernel_regularizer=regularizers.l2(0.01))(x)
    x = Dropout(0.5)(x)
    out = Dense(1, activation="sigmoid")(x)

    model = Model([input_1, input_2], out)

    model.compile(loss="binary_crossentropy", metrics=['acc'], optimizer=Adam(0.00001))

    model.summary()

    return model

# %%
file_path = "vggface6.h5"

checkpoint = ModelCheckpoint(file_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

reduce_on_plateau = ReduceLROnPlateau(monitor="val_acc", mode="max", factor=0.1, patience=10, verbose=1)

early_stop = EarlyStopping(monitor='loss', patience=5)

callbacks_list = [checkpoint, reduce_on_plateau, early_stop]

model6 = baseline_model6()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_16 (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# input_17 (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# vggface_resnet50 (Functional)   (None, None, None, 2 23561152    input_16[0][0]
#                                                                  input_17[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_10 (Global (None, 2048)         0           vggface_resnet50[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_10 (Gl (None, 2048)         0           vggface_resnet50[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_11 (Global (None, 2048)         0           vggface_resnet50[1][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_11 (Gl (None, 2048)         0           vggface_resnet50[1][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 4096)         0           global_max_pooling2d_10[0][0]
#                                                                  global_average_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 4096)         0           global_max_pooling2d_11[0][0]
#                                                                  global_average_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 4096)         0           concatenate_15[0][0]
#                                                                  concatenate_16[0][0]
# __________________________________________________________________________________________________
# add_98 (Add)                    (None, 4096)         0           concatenate_15[0][0]
#                                                                  concatenate_16[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 8192)         0           multiply_11[0][0]
#                                                                  add_98[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 512)          4194816     concatenate_17[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 512)          0           dense_10[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 1)            513         dropout_5[0][0]
# ==================================================================================================
# Total params: 27,756,481
# Trainable params: 27,703,361
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
model6.fit(gen(train, train_person_to_images_map, batch_size=16), use_multiprocessing=True,
                    validation_data=gen(val, val_person_to_images_map, batch_size=16), epochs=50, verbose=2,
                    workers=4, callbacks=callbacks_list, steps_per_epoch=100, validation_steps=50)
# Out:
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# Epoch 1/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# Epoch 00001: val_acc improved from -inf to 0.60000, saving model to vggface6.h5
# 100/100 - 71s - loss: 11.5168 - acc: 0.5444 - val_loss: 10.9000 - val_acc: 0.6000
# Epoch 2/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00002: val_acc improved from 0.60000 to 0.66000, saving model to vggface6.h5
# 100/100 - 37s - loss: 11.0135 - acc: 0.5756 - val_loss: 10.3701 - val_acc: 0.6600
# Epoch 3/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00003: val_acc improved from 0.66000 to 0.66500, saving model to vggface6.h5
# 100/100 - 36s - loss: 10.4383 - acc: 0.6400 - val_loss: 10.2073 - val_acc: 0.6650
# Epoch 4/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00004: val_acc did not improve from 0.66500
# 100/100 - 34s - loss: 10.2497 - acc: 0.6325 - val_loss: 10.2646 - val_acc: 0.6250
# Epoch 5/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00005: val_acc did not improve from 0.66500
# 100/100 - 34s - loss: 10.1435 - acc: 0.6225 - val_loss: 10.0224 - val_acc: 0.6513
# Epoch 6/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00006: val_acc did not improve from 0.66500
# 100/100 - 35s - loss: 10.0252 - acc: 0.6319 - val_loss: 9.9041 - val_acc: 0.6625
# Epoch 7/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00007: val_acc improved from 0.66500 to 0.67000, saving model to vggface6.h5
# 100/100 - 36s - loss: 9.8947 - acc: 0.6525 - val_loss: 9.8182 - val_acc: 0.6700
# Epoch 8/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00008: val_acc did not improve from 0.67000
# 100/100 - 34s - loss: 9.7955 - acc: 0.6938 - val_loss: 9.7771 - val_acc: 0.6662
# Epoch 9/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00009: val_acc improved from 0.67000 to 0.72625, saving model to vggface6.h5
# 100/100 - 37s - loss: 9.6961 - acc: 0.6994 - val_loss: 9.6045 - val_acc: 0.7262
# Epoch 10/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00010: val_acc did not improve from 0.72625
# 100/100 - 34s - loss: 9.6053 - acc: 0.7175 - val_loss: 9.5458 - val_acc: 0.7088
# Epoch 11/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00011: val_acc improved from 0.72625 to 0.77500, saving model to vggface6.h5
# 100/100 - 37s - loss: 9.5375 - acc: 0.7094 - val_loss: 9.4163 - val_acc: 0.7750
# Epoch 12/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00012: val_acc did not improve from 0.77500
# 100/100 - 34s - loss: 9.4729 - acc: 0.7212 - val_loss: 9.3890 - val_acc: 0.7287
# Epoch 13/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00013: val_acc did not improve from 0.77500
# 100/100 - 35s - loss: 9.3739 - acc: 0.7181 - val_loss: 9.3111 - val_acc: 0.7538
# Epoch 14/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00014: val_acc did not improve from 0.77500
# 100/100 - 35s - loss: 9.3011 - acc: 0.7206 - val_loss: 9.2110 - val_acc: 0.7362
# Epoch 15/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00015: val_acc did not improve from 0.77500
# 100/100 - 34s - loss: 9.1947 - acc: 0.7431 - val_loss: 9.0888 - val_acc: 0.7738
# Epoch 16/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00016: val_acc did not improve from 0.77500
# 100/100 - 35s - loss: 9.1104 - acc: 0.7519 - val_loss: 9.0411 - val_acc: 0.7750
# Epoch 17/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00017: val_acc did not improve from 0.77500
# 100/100 - 35s - loss: 9.0345 - acc: 0.7387 - val_loss: 8.9765 - val_acc: 0.7487
# Epoch 18/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00018: val_acc did not improve from 0.77500
# 100/100 - 35s - loss: 8.9271 - acc: 0.7569 - val_loss: 8.8903 - val_acc: 0.7588
# Epoch 19/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00019: val_acc did not improve from 0.77500
# 100/100 - 34s - loss: 8.8373 - acc: 0.7650 - val_loss: 8.8352 - val_acc: 0.7513
# Epoch 20/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00020: val_acc did not improve from 0.77500
# 100/100 - 35s - loss: 8.7560 - acc: 0.7588 - val_loss: 8.7674 - val_acc: 0.7688
# Epoch 21/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00021: val_acc did not improve from 0.77500
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 100/100 - 40s - loss: 8.6747 - acc: 0.7644 - val_loss: 8.6230 - val_acc: 0.7725
# Epoch 22/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00022: val_acc did not improve from 0.77500
# 100/100 - 34s - loss: 8.6381 - acc: 0.7575 - val_loss: 8.6037 - val_acc: 0.7700
# Epoch 23/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00023: val_acc did not improve from 0.77500
# 100/100 - 35s - loss: 8.6278 - acc: 0.7500 - val_loss: 8.5973 - val_acc: 0.7625
# Epoch 24/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00024: val_acc improved from 0.77500 to 0.77625, saving model to vggface6.h5
# 100/100 - 36s - loss: 8.5800 - acc: 0.7794 - val_loss: 8.5860 - val_acc: 0.7763
# Epoch 25/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00025: val_acc did not improve from 0.77625
# 100/100 - 34s - loss: 8.6064 - acc: 0.7569 - val_loss: 8.5924 - val_acc: 0.7625
# Epoch 26/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00026: val_acc improved from 0.77625 to 0.78375, saving model to vggface6.h5
# 100/100 - 36s - loss: 8.5926 - acc: 0.7538 - val_loss: 8.5432 - val_acc: 0.7837
# Epoch 27/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00027: val_acc did not improve from 0.78375
# 100/100 - 34s - loss: 8.5569 - acc: 0.7781 - val_loss: 8.5834 - val_acc: 0.7600
# Epoch 28/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00028: val_acc did not improve from 0.78375
# 100/100 - 35s - loss: 8.5514 - acc: 0.7719 - val_loss: 8.5634 - val_acc: 0.7738
# Epoch 29/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00029: val_acc did not improve from 0.78375
# 100/100 - 34s - loss: 8.5504 - acc: 0.7575 - val_loss: 8.5334 - val_acc: 0.7738
# Epoch 30/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00030: val_acc did not improve from 0.78375
# 100/100 - 35s - loss: 8.5155 - acc: 0.7788 - val_loss: 8.5221 - val_acc: 0.7775
# Epoch 31/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00031: val_acc did not improve from 0.78375
# 100/100 - 34s - loss: 8.5271 - acc: 0.7650 - val_loss: 8.5375 - val_acc: 0.7788
# Epoch 32/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00032: val_acc improved from 0.78375 to 0.79625, saving model to vggface6.h5
# 100/100 - 37s - loss: 8.4999 - acc: 0.7738 - val_loss: 8.4816 - val_acc: 0.7962
# Epoch 33/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00033: val_acc did not improve from 0.79625
# 100/100 - 34s - loss: 8.5023 - acc: 0.7725 - val_loss: 8.5024 - val_acc: 0.7725
# Epoch 34/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00034: val_acc did not improve from 0.79625
# 100/100 - 35s - loss: 8.4692 - acc: 0.7919 - val_loss: 8.5367 - val_acc: 0.7525
# Epoch 35/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00035: val_acc did not improve from 0.79625
# 100/100 - 35s - loss: 8.4897 - acc: 0.7694 - val_loss: 8.4355 - val_acc: 0.7638
# Epoch 36/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00036: val_acc did not improve from 0.79625
# 100/100 - 35s - loss: 8.4393 - acc: 0.7800 - val_loss: 8.4412 - val_acc: 0.7763
# Epoch 37/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00037: val_acc did not improve from 0.79625
# 100/100 - 35s - loss: 8.4258 - acc: 0.7919 - val_loss: 8.4500 - val_acc: 0.7900
# Epoch 38/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00038: val_acc improved from 0.79625 to 0.80000, saving model to vggface6.h5
# 100/100 - 36s - loss: 8.4115 - acc: 0.7906 - val_loss: 8.4113 - val_acc: 0.8000
# Epoch 39/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00039: val_acc did not improve from 0.80000
# 100/100 - 34s - loss: 8.4032 - acc: 0.7906 - val_loss: 8.3687 - val_acc: 0.7925
# Epoch 40/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00040: val_acc did not improve from 0.80000
# 100/100 - 34s - loss: 8.4167 - acc: 0.7744 - val_loss: 8.4224 - val_acc: 0.7812
# Epoch 41/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00041: val_acc did not improve from 0.80000
# 100/100 - 35s - loss: 8.3720 - acc: 0.7881 - val_loss: 8.3564 - val_acc: 0.7962
# Epoch 42/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00042: val_acc did not improve from 0.80000
# 100/100 - 34s - loss: 8.3517 - acc: 0.7875 - val_loss: 8.3896 - val_acc: 0.7450
# Epoch 43/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00043: val_acc did not improve from 0.80000
# 100/100 - 35s - loss: 8.3500 - acc: 0.7850 - val_loss: 8.3739 - val_acc: 0.7700
# Epoch 44/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00044: val_acc did not improve from 0.80000
# 100/100 - 35s - loss: 8.3333 - acc: 0.7931 - val_loss: 8.3702 - val_acc: 0.7825
# Epoch 45/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00045: val_acc did not improve from 0.80000
# 100/100 - 35s - loss: 8.3079 - acc: 0.7781 - val_loss: 8.3251 - val_acc: 0.7887
# Epoch 46/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00046: val_acc did not improve from 0.80000
# 100/100 - 34s - loss: 8.3049 - acc: 0.7994 - val_loss: 8.3308 - val_acc: 0.7750
# Epoch 47/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00047: val_acc did not improve from 0.80000
# 100/100 - 35s - loss: 8.2730 - acc: 0.7975 - val_loss: 8.2806 - val_acc: 0.7812
# Epoch 48/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00048: val_acc did not improve from 0.80000
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# 100/100 - 35s - loss: 8.2492 - acc: 0.8025 - val_loss: 8.2577 - val_acc: 0.7887
# Epoch 49/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00049: val_acc improved from 0.80000 to 0.82625, saving model to vggface6.h5
# 100/100 - 37s - loss: 8.2808 - acc: 0.7694 - val_loss: 8.2209 - val_acc: 0.8263
# Epoch 50/50
# WARNING:tensorflow:Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the `keras.utils.Sequence` class.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
#
# Epoch 00050: val_acc did not improve from 0.82625
# 100/100 - 35s - loss: 8.2599 - acc: 0.7912 - val_loss: 8.2687 - val_acc: 0.7850
